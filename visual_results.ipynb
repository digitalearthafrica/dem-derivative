# %%
import xarray as xr

# %%
# !ls *.tif
# Out:
# aspect_8_8.tif	roughness_8_8.tif  tpi_8_8.tif	tri_8_8.tif

# %%
data = xr.open_rasterio('aspect_8_8.tif').squeeze()
data.plot.imshow(robust=True);

# %%
data = xr.open_rasterio('tri_8_8.tif').squeeze()
data.plot.imshow(robust=True);

# %%
data = xr.open_rasterio('tpi_8_8.tif').squeeze()
data.plot.imshow(robust=True);

# %%
data = xr.open_rasterio('roughness_8_8.tif').squeeze()
data.plot.imshow(robust=True);
